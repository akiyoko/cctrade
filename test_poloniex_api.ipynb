# %%
import requests

res = requests.get('https://poloniex.com/public?command=returnTicker')
res_json = res.json()
res_json
# Out:
# {u'BTC_AMP': {u'baseVolume': u'239.18275250',
#   u'high24hr': u'0.00023424',
#   u'highestBid': u'0.00020786',
#   u'id': 160,
#   u'isFrozen': u'0',
#   u'last': u'0.00020890',
#   u'low24hr': u'0.00020600',
#   u'lowestAsk': u'0.00020888',
#   u'percentChange': u'-0.10431762',
#   u'quoteVolume': u'1074511.54097832'},
#  u'BTC_ARDR': {u'baseVolume': u'1378.43426130',
#   u'high24hr': u'0.00011200',
#   u'highestBid': u'0.00010009',
#   u'id': 177,
#   u'isFrozen': u'0',
#   u'last': u'0.00010196',
#   u'low24hr': u'0.00009303',
#   u'lowestAsk': u'0.00010196',
#   u'percentChange': u'0.03565261',
#   u'quoteVolume': u'13485138.07750936'},
#  u'BTC_BCN': {u'baseVolume': u'391.25644980',
#   u'high24hr': u'0.00000118',
#   u'highestBid': u'0.00000107',
#   u'id': 7,
#   u'isFrozen': u'0',
#   u'last': u'0.00000108',
#   u'low24hr': u'0.00000107',
#   u'lowestAsk': u'0.00000108',
#   u'percentChange': u'-0.07692307',
#   u'quoteVolume': u'341470589.03223473'},
# ...

# %%
from urllib2 import urlopen, Request
import json

res = urlopen(Request('https://poloniex.com/public?command=returnTicker'))
res_json = json.loads(res.read())
res_json
# Out:
# {u'BTC_AMP': {u'baseVolume': u'239.18275250',
#   u'high24hr': u'0.00023424',
#   u'highestBid': u'0.00020786',
#   u'id': 160,
#   u'isFrozen': u'0',
#   u'last': u'0.00020890',
#   u'low24hr': u'0.00020600',
#   u'lowestAsk': u'0.00020888',
#   u'percentChange': u'-0.10431762',
#   u'quoteVolume': u'1074511.54097832'},
#  u'BTC_ARDR': {u'baseVolume': u'1378.43426130',
#   u'high24hr': u'0.00011200',
#   u'highestBid': u'0.00010009',
#   u'id': 177,
#   u'isFrozen': u'0',
#   u'last': u'0.00010196',
#   u'low24hr': u'0.00009303',
#   u'lowestAsk': u'0.00010196',
#   u'percentChange': u'0.03565261',
#   u'quoteVolume': u'13485138.07750936'},
#  u'BTC_BCN': {u'baseVolume': u'391.25644980',
#   u'high24hr': u'0.00000118',
#   u'highestBid': u'0.00000107',
#   u'id': 7,
#   u'isFrozen': u'0',
#   u'last': u'0.00000108',
#   u'low24hr': u'0.00000107',
#   u'lowestAsk': u'0.00000108',
#   u'percentChange': u'-0.07692307',
#   u'quoteVolume': u'341470589.03223473'},
# ...
